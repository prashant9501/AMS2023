# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# **Univariate Plots:**
# 1. For continous var: Histograms, KDE, Box and Whisker plots
# 2. For Cat. var: Barchart, pie-chart
#
# NotE: what hist() & plt.kde() is for pandas, histplot() in seaborn already has kde option
# barchart in pandas ... countplot() in seaborn
#
#
# **For Bivariate Plots:**
# 1. Scatter plot for 2 numeric variables
# 2. 1 numeric & 1 cat. variable: box-whisker plot, violin plot,
#
# Multivariate Plots:
# 1. Plotting 3 numeric variables: Bubble charts
# 2. Between 1 numeric & 2 cat variables, use the "hue" option in barplots

# %%
pd.read_csv("churn_prediction.csv")
# Out:
#        customer_id  vintage  age  gender  dependents     occupation    city  \
# 0                1     2401   66    Male         0.0  self_employed   187.0
# 1                2     2648   35    Male         0.0  self_employed     NaN
# 2                4     2494   31    Male         0.0       salaried   146.0
# 3                5     2629   90     NaN         NaN  self_employed  1020.0
# 4                6     1879   42    Male         2.0  self_employed  1494.0
# ...            ...      ...  ...     ...         ...            ...     ...
# 15925        16993     2500   64  Female         0.0  self_employed   409.0
# 15926        16994     2470   44    Male         0.0       salaried  1020.0
# 15927        16995     2537   34  Female         1.0  self_employed   557.0
# 15928        16996     2287   56  Female         0.0  self_employed  1540.0
# 15929        16997     2656   70    Male         0.0  self_employed  1096.0
#
#        customer_nw_category  branch_code  current_balance  ...  \
# 0                         2          755          1458.71  ...
# 1                         2         3214          5390.37  ...
# 2                         2           41          3913.16  ...
# 3                         2          582          2291.91  ...
# 4                         3          388           927.72  ...
# ...                     ...          ...              ...  ...
# 15925                     3          934           309.64  ...
# 15926                     2           15          1049.67  ...
# 15927                     2          284          1106.86  ...
# 15928                     2          670          2098.29  ...
# 15929                     2          134         18530.60  ...
#
#        average_monthly_balance_prevQ  average_monthly_balance_prevQ2  \
# 0                            1458.71                         1449.07
# 1                            7799.26                        12419.41
# 2                            4910.17                         2815.94
# 3                            2084.54                         1006.54
# 4                            1643.31                         1871.12
# ...                              ...                             ...
# 15925                        1738.15                          300.91
# 15926                        3622.00                         6016.92
# 15927                        2729.22                         2170.80
# 15928                        2122.82                         2131.59
# 15929                       18199.41                        17473.74
#
#        current_month_credit  previous_month_credit  current_month_debit  \
# 0                      0.20                   0.20                 0.20
# 1                      0.56                   0.56              5486.27
# 2                      0.61                   0.61              6046.73
# 3                      0.47                   0.47                 0.47
# 4                      0.33                 714.61               588.62
# ...                     ...                    ...                  ...
# 15925                  0.04               46961.44              5148.76
# 15926                  0.06                 966.96              1428.63
# 15927               8732.47                1714.39              8618.20
# 15928                362.14                   0.26               143.11
# 15929                150.27                 156.55                 0.19
#
#        previous_month_debit  current_month_balance  previous_month_balance  \
# 0                      0.20                1458.71                 1458.71
# 1                    100.56                6496.78                 8787.61
# 2                    259.23                5006.28                 5070.14
# 3                   2143.33                2291.91                 1669.79
# 4                   1538.06                1157.15                 1677.16
# ...                     ...                    ...                     ...
# 15925              41642.90                2733.69                 2340.96
# 15926               5714.34                2100.30                 1846.93
# 15927               1142.96                5726.47                  605.49
# 15928                314.54                2132.49                 2083.49
# 15929                   NaN                    NaN                     NaN
#
#        last_transaction churn
# 0            2019-05-21   0.0
# 1            2019-11-01   0.0
# 2                   NaT   0.0
# 3            2019-08-06   1.0
# 4            2019-11-03   1.0
# ...                 ...   ...
# 15925        2019-11-28   1.0
# 15926        2019-12-01   1.0
# 15927        2019-12-07   0.0
# 15928        2019-12-07   0.0
# 15929               NaN   NaN
#
# [15930 rows x 21 columns]

# %%
import pandas as pd

# %%
df = pd.read_pickle("churn_prediction_v3.pkl")

# %%
df.head()
# Out:
#    vintage  age gender  dependents     occupation    city  \
# 0     2401   66   Male           0  self_employed     187
# 1     2648   35   Male           0  self_employed  100000
# 2     2494   31   Male           0       salaried     146
# 3     2629   90   Male           1  self_employed    1020
# 4     1879   42   Male           2  self_employed    1494
#
#   customer_nw_category branch_code  current_balance  \
# 0                    2         755          1458.71
# 1                    2        3214          5390.37
# 2                    2          41          3913.16
# 3                    2         582          2291.91
# 4                    3         388           927.72
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# 0                     1458.71                        1458.71
# 1                     8704.66                        7799.26
# 2                     5815.29                        4910.17
# 3                     2291.91                        2084.54
# 4                     1401.72                        1643.31
#
#    average_monthly_balance_prevQ2  current_month_credit  \
# 0                         1449.07                  0.20
# 1                        12419.41                  0.56
# 2                         2815.94                  0.61
# 3                         1006.54                  0.47
# 4                         1871.12                  0.33
#
#    previous_month_credit  current_month_debit  previous_month_debit  \
# 0                   0.20                 0.20                  0.20
# 1                   0.56              5486.27                100.56
# 2                   0.61              6046.73                259.23
# 3                   0.47                 0.47               2143.33
# 4                 714.61               588.62               1538.06
#
#    current_month_balance  previous_month_balance churn
# 0                1458.71                 1458.71   0.0
# 1                6496.78                 8787.61   0.0
# 2                5006.28                 5070.14   0.0
# 3                2291.91                 1669.79   1.0
# 4                1157.15                 1677.16   1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15929 entries, 0 to 15928
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   vintage                         15929 non-null  int64
#  1   age                             15929 non-null  int64
#  2   gender                          15929 non-null  category
#  3   dependents                      15929 non-null  int64
#  4   occupation                      15929 non-null  category
#  5   city                            15929 non-null  category
#  6   customer_nw_category            15929 non-null  category
#  7   branch_code                     15929 non-null  category
#  8   current_balance                 15929 non-null  float64
#  9   previous_month_end_balance      15929 non-null  float64
#  10  average_monthly_balance_prevQ   15929 non-null  float64
#  11  average_monthly_balance_prevQ2  15929 non-null  float64
#  12  current_month_credit            15929 non-null  float64
#  13  previous_month_credit           15929 non-null  float64
#  14  current_month_debit             15929 non-null  float64
#  15  previous_month_debit            15929 non-null  float64
#  16  current_month_balance           15929 non-null  float64
#  17  previous_month_balance          15929 non-null  float64
#  18  churn                           15929 non-null  category
# dtypes: category(6), float64(10), int64(3)
# memory usage: 1.7 MB

# %% [markdown]
# ### Basic Information
# - **Dataset Shape**: The dataset contains 15,929 rows and 19 columns.
# - **Data Types**: The columns comprise a mix of numerical (`float64`) and categorical data (`object` for strings).
# - **Missing Values**: There are no missing values in the dataset.
# - **Unique Values**: The dataset has a wide range of unique values across different columns, indicating a diverse dataset.
#
# ### Columns Overview
# - **`vintage`**: Customer relationship duration with the bank (1,332 unique values).
# - **`age`**: Age of the customer (90 unique values).
# - **`gender`**: Gender of the customer (2 unique values - presumably male and female).
# - **`dependents`**: Number of dependents of the customer (14 unique values).
# - **`occupation`**: Occupation of the customer (5 unique categories).
# - **`city`**: City codes (1,288 unique values).
# - **`customer_nw_category`**: Customer net worth category (3 unique categories).
# - **`branch_code`**: Code of the branch (2,806 unique values).
# - **Financial columns**: Several columns like `current_balance`, `previous_month_end_balance`, `average_monthly_balance_prevQ`, and similar others indicating various aspects of the customer's account balance and transactions.
# - **`churn`**: Customer churn status (2 unique values, likely indicating churned or not churned).
#
# ### Exploratory Data Analysis (EDA) Steps:
# 1. **Statistical Summary**: Analyze the statistical summary of numerical columns to understand the distribution, mean, median, etc.
# 2. **Correlation Analysis**: Check the correlation between different numerical features, especially with respect to the target variable `churn`.
# 3. **Categorical Data Analysis**: Analyze the categorical data like gender, occupation, and customer net worth category, and their relation to churn.
# 4. **Data Visualization**: Use plots like histograms, box plots, and bar charts for the distribution of various features and scatter plots or pair plots for relationships between features.
# 5. **Churn Analysis**: Specifically analyze the `churn` column in relation to other features to identify any patterns or trends that might be indicative of customer churn.
#
# Let's proceed with a more detailed exploratory data analysis, starting with the statistical summary and then moving on to visualizations and correlation analysis.
#
# ### Exploratory Data Analysis (EDA) Summary:
#
# #### Statistical Summary of Numerical Columns:
# The dataset has a range of numerical columns, each providing different insights:
#
# - **`vintage`**: Shows variability with a mean of around 2392 days and a standard deviation of 272 days.
# - **`age`**: The average age of customers is around 48 years, with a standard deviation of approximately 18 years, indicating a diverse age group.
# - **`current_balance`**, **`previous_month_end_balance`**, **`average_monthly_balance_prevQ`**, and **`average_monthly_balance_prevQ2`** show significant variation, with high standard deviations, indicating a wide range of account balances among customers.
# - **Transaction-related columns** (`current_month_credit`, `previous_month_credit`, `current_month_debit`, `previous_month_debit`): Also show wide variation, reflecting diverse transaction behaviors.
#
# #### Correlation Analysis:
# - **Customer Balance and Transactions**: There's a strong positive correlation among different balance-related columns (like `current_balance`, `previous_month_end_balance`, etc.), which is expected as they represent related aspects of a customer's account.
# - **Churn**: The correlation of other features with the `churn` column is relatively low, suggesting no single strong linear predictor for churn. However, `current_month_debit`, `previous_month_debit`, and `branch_code` show some level of positive correlation with churn, indicating they might be factors in predicting churn.
#
# #### Data Visualization Insights:
# - **Heatmap of Correlation Matrix**: Provides a visual representation of the correlations between different variables. Darker shades represent stronger correlations (positive or negative).
# - **Churn Analysis**: A detailed analysis of the `churn` column in relation to other features is essential. For example, understanding how balance and transaction behaviors correlate with churn can provide valuable insights into customer behavior.
#
# ### Further EDA Steps:
# 1. **Distribution Plots**: For understanding the distribution of key variables like age, balance, and transaction amounts.
# 2. **Bar Charts for Categorical Variables**: To analyze the distribution of gender, occupation, and customer net worth categories.
# 3. **Churn Analysis**: Detailed analysis of churned vs. non-churned customers across different variables.
# 4. **Box Plots**: To visualize the spread and outliers in numerical data.
# 5. **Scatter Plots**: To investigate the relationships between pairs of variables.

# %%
df.describe().T.round(2)  # quick statistical summary of the numeric variables
# Out:
#                                   count     mean       std       min      25%  \
# vintage                         15929.0  2392.42    272.49    438.00  2260.00
# age                             15929.0    48.17     17.87      1.00    35.00
# dependents                      15929.0     0.37      1.05      0.00     0.00
# current_balance                 15929.0  7270.71  50513.41  -5503.96  1776.37
# previous_month_end_balance      15929.0  7386.31  49443.90  -2998.64  1908.42
# average_monthly_balance_prevQ   15929.0  7432.82  48936.87   1428.69  2168.03
# average_monthly_balance_prevQ2  15929.0  7183.14  55287.42 -16506.10  1821.85
# current_month_credit            15929.0  3279.40  31248.24      0.01     0.31
# previous_month_credit           15929.0  3419.69  35413.78      0.01     0.33
# current_month_debit             15929.0  3498.42  28258.15      0.01     0.41
# previous_month_debit            15929.0  3466.23  27720.81      0.01     0.41
# current_month_balance           15929.0  7362.58  49338.07  -3374.18  1988.66
# previous_month_balance          15929.0  7438.76  49736.15  -3060.13  2077.04
#
#                                     50%      75%         max
# vintage                         2454.00  2593.00     2776.00
# age                               46.00    60.00       90.00
# dependents                         0.00     0.00       52.00
# current_balance                 3276.34  6624.21  5905904.03
# previous_month_end_balance      3380.62  6685.81  5740438.63
# average_monthly_balance_prevQ   3520.02  6675.25  5700289.57
# average_monthly_balance_prevQ2  3373.32  6532.50  5010170.10
# current_month_credit               0.61   707.59  1764285.97
# previous_month_credit              0.64   771.87  2361808.29
# current_month_debit               94.50  1393.64  1764285.97
# previous_month_debit             112.48  1357.73  1414168.06
# current_month_balance           3445.41  6658.49  5778184.77
# previous_month_balance          3450.51  6679.81  5720144.50

# %%
df.describe(include='category')
# Out:
#        gender     occupation   city  customer_nw_category  branch_code  \
# count   15929          15929  15929                 15929        15929
# unique      2              5   1288                     3         2806
# top      Male  self_employed   1020                     2            6
# freq     9595           9860   1949                  8163           75
#
#           churn
# count   15929.0
# unique      2.0
# top         0.0
# freq    12942.0

# %%
# Correlation Analysis
corr_mat = df.corr().round(2)
corr_mat
# Out:
# C:\Users\Prashant\AppData\Local\Temp\ipykernel_20684\4052411543.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_mat = df.corr().round(2)
#                                 vintage   age  dependents  current_balance  \
# vintage                            1.00 -0.01       -0.00            -0.00
# age                               -0.01  1.00        0.01             0.05
# dependents                        -0.00  0.01        1.00             0.00
# current_balance                   -0.00  0.05        0.00             1.00
# previous_month_end_balance         0.00  0.05        0.01             0.96
# average_monthly_balance_prevQ     -0.00  0.05        0.01             0.97
# average_monthly_balance_prevQ2    -0.00  0.05        0.01             0.72
# current_month_credit              -0.00  0.04        0.02             0.08
# previous_month_credit             -0.00  0.03        0.02             0.05
# current_month_debit               -0.00  0.04        0.02             0.05
# previous_month_debit              -0.01  0.03        0.03             0.06
# current_month_balance             -0.00  0.05        0.01             0.99
# previous_month_balance            -0.00  0.05        0.01             0.96
# churn                             -0.01 -0.02        0.03            -0.02
#
#                                 previous_month_end_balance  \
# vintage                                               0.00
# age                                                   0.05
# dependents                                            0.01
# current_balance                                       0.96
# previous_month_end_balance                            1.00
# average_monthly_balance_prevQ                         0.97
# average_monthly_balance_prevQ2                        0.72
# current_month_credit                                  0.08
# previous_month_credit                                 0.11
# current_month_debit                                   0.11
# previous_month_debit                                  0.09
# current_month_balance                                 0.98
# previous_month_balance                                0.97
# churn                                                -0.00
#
#                                 average_monthly_balance_prevQ  \
# vintage                                                 -0.00
# age                                                      0.05
# dependents                                               0.01
# current_balance                                          0.97
# previous_month_end_balance                               0.97
# average_monthly_balance_prevQ                            1.00
# average_monthly_balance_prevQ2                           0.76
# current_month_credit                                     0.10
# previous_month_credit                                    0.08
# current_month_debit                                      0.10
# previous_month_debit                                     0.11
# current_month_balance                                    0.98
# previous_month_balance                                   1.00
# churn                                                    0.01
#
#                                 average_monthly_balance_prevQ2  \
# vintage                                                  -0.00
# age                                                       0.05
# dependents                                                0.01
# current_balance                                           0.72
# previous_month_end_balance                                0.72
# average_monthly_balance_prevQ                             0.76
# average_monthly_balance_prevQ2                            1.00
# current_month_credit                                      0.06
# previous_month_credit                                     0.06
# current_month_debit                                       0.06
# previous_month_debit                                      0.09
# current_month_balance                                     0.73
# previous_month_balance                                    0.73
# churn                                                     0.02
#
#                                 current_month_credit  previous_month_credit  \
# vintage                                        -0.00                  -0.00
# age                                             0.04                   0.03
# dependents                                      0.02                   0.02
# current_balance                                 0.08                   0.05
# previous_month_end_balance                      0.08                   0.11
# average_monthly_balance_prevQ                   0.10                   0.08
# average_monthly_balance_prevQ2                  0.06                   0.06
# current_month_credit                            1.00                   0.57
# previous_month_credit                           0.57                   1.00
# current_month_debit                             0.80                   0.39
# previous_month_debit                            0.46                   0.74
# current_month_balance                           0.09                   0.08
# previous_month_balance                          0.11                   0.10
# churn                                           0.02                   0.03
#
#                                 current_month_debit  previous_month_debit  \
# vintage                                       -0.00                 -0.01
# age                                            0.04                  0.03
# dependents                                     0.02                  0.03
# current_balance                                0.05                  0.06
# previous_month_end_balance                     0.11                  0.09
# average_monthly_balance_prevQ                  0.10                  0.11
# average_monthly_balance_prevQ2                 0.06                  0.09
# current_month_credit                           0.80                  0.46
# previous_month_credit                          0.39                  0.74
# current_month_debit                            1.00                  0.46
# previous_month_debit                           0.46                  1.00
# current_month_balance                          0.10                  0.08
# previous_month_balance                         0.11                  0.13
# churn                                          0.06                  0.06
#
#                                 current_month_balance  previous_month_balance  \
# vintage                                         -0.00                   -0.00
# age                                              0.05                    0.05
# dependents                                       0.01                    0.01
# current_balance                                  0.99                    0.96
# previous_month_end_balance                       0.98                    0.97
# average_monthly_balance_prevQ                    0.98                    1.00
# average_monthly_balance_prevQ2                   0.73                    0.73
# current_month_credit                             0.09                    0.11
# previous_month_credit                            0.08                    0.10
# current_month_debit                              0.10                    0.11
# previous_month_debit                             0.08                    0.13
# current_month_balance                            1.00                    0.97
# previous_month_balance                           0.97                    1.00
# churn                                           -0.01                    0.01
#
#                                 churn
# vintage                         -0.01
# age                             -0.02
# dependents                       0.03
# current_balance                 -0.02
# previous_month_end_balance      -0.00
# average_monthly_balance_prevQ    0.01
# average_monthly_balance_prevQ2   0.02
# current_month_credit             0.02
# previous_month_credit            0.03
# current_month_debit              0.06
# previous_month_debit             0.06
# current_month_balance           -0.01
# previous_month_balance           0.01
# churn                            1.00

# %%
# Plotting the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(corr_mat, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# # Univariate Plots
# For continous var: hist, kde, box-plots
#
# For categorical var: bar charts, pie charts

# %%
df['age'].hist(bins=20, figsize=(10,6))
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
df[['age', 'dependents']].hist(bins=20)
plt.show()

# %%
# https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %%
plt.style.use('seaborn')
df[['age', 'dependents']].hist(bins=20)
plt.show()
# Out:
# C:\Users\Prashant\AppData\Local\Temp\ipykernel_20684\1440878617.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
plt.style.use('ggplot')
df[['age', 'dependents']].hist(bins=20)
plt.show()

# %%
plt.style.use('dark_background')
df[['age', 'dependents']].hist(bins=20)
plt.show()

# %%
plt.style.use('seaborn-v0_8')
df[['age', 'dependents']].hist(bins=20)
plt.show()

# %%
df['age'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['age'].plot.kde()  # Kernel Density Estimation plot from Pandas >>> Gives the shape of the histogram.
plt.xlim([-5, 100])
# Out:
# (-5.0, 100.0)

# %%
df['dependents'].plot.kde()
plt.xlim([-1, 80])
# Out:
# (-1.0, 80.0)

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.12.2'

# %%
sns.histplot(df['age'], kde=True, color='darkred', bins=30)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# Plotting the bar chart
occupation_counts = df['occupation'].value_counts()
occupation_counts.plot(kind='bar')

plt.xlabel('Occupation')
plt.ylabel('Count')
plt.title('Occupation Distribution')
plt.show()

# %%
# Using seaborn's countplot to create a bar chart of the 'occupation' column
import seaborn as sns

sns.countplot(data=df, x='occupation')
plt.title('Occupation Distribution with Seaborn')
plt.show()

# %%
plt.figure(figsize=(8,6))

# Plotting a pie chart for the 'occupation' column
occupation_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.ylabel('')  # Hiding the y-label
plt.title('Occupation Distribution (Pie Chart)')
plt.show()

# %%
# Further detailed visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# Setting up the figure size and layout for multiple plots
plt.figure(figsize=(20, 15))
plt.subplots_adjust(hspace=0.5)

# Distribution of Age
plt.subplot(2, 2, 1)
sns.histplot(df['age'], bins=30, kde=True)
plt.title('Distribution of Age')

# Distribution of Current Balance
plt.subplot(2, 2, 2)
sns.histplot(df[df['current_balance'] < 20000]['current_balance'], bins=30, kde=True)  # Limiting to a smaller range for clarity
plt.title('Distribution of Current Balance')

# Distribution of Gender
plt.subplot(2, 2, 3)
sns.countplot(x='gender', data=df)
plt.title('Distribution of Gender')

# Distribution of Occupation
plt.subplot(2, 2, 4)
sns.countplot(x='occupation', data=df)
plt.xticks(rotation=45)
plt.title('Distribution of Occupation')

plt.show()

# %%
sns.boxplot(x=df['age'])
plt.title(f'Box Plot of Age')
# Out:
# Text(0.5, 1.0, 'Box Plot of Age')

# %%
sns.boxplot(x=df['vintage'])
plt.title(f'Box Plot of Vintage')
# Out:
# Text(0.5, 1.0, 'Box Plot of Vintage')

# %% [markdown]
# # Bivariate Plots

# %%
# Plotting the scatter plot
sample = df.sample(100)

plt.scatter(sample['age'], sample['vintage'], marker='o')
plt.xlabel('Age')
plt.ylabel('Vintage')
plt.title('Scatter Plot of Age vs Vintage')
plt.show()

# %%
# Creating a bubble chart
plt.scatter(sample['age'], sample['vintage'], s=0.01*sample['current_balance'])
plt.xlabel('Age')
plt.ylabel('Vintage')
plt.title('Bubble Chart: Age vs Vintage (Size by Current Balance)')
plt.show()

# %%
plt.figure(figsize=(20, 10))

# Churn Rate by Occupation
df['churn'] = df['churn'].astype("Int32")

plt.subplot(1, 2, 1)
sns.barplot(x='occupation', y='churn', data=df)
plt.xticks(rotation=45)
plt.title('Churn Rate by Occupation')

# Box Plot for Age vs Churn
plt.subplot(1, 2, 2)
sns.boxplot(x='churn', y='age', data=df)
plt.title('Age vs Churn')
# Out:
# Text(0.5, 1.0, 'Age vs Churn')

# %%
df.groupby(by="gender")["vintage"].describe().round(2)
# Out:
#          count     mean     std    min      25%     50%     75%     max
# gender
# Female  6334.0  2396.93  265.84  769.0  2263.25  2459.0  2593.0  2776.0
# Male    9595.0  2389.45  276.76  438.0  2258.00  2450.0  2592.0  2776.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='gender', y='vintage', data=df)
plt.title('Gender vs vintage')
# Out:
# Text(0.5, 1.0, 'Gender vs vintage')

# %%
# Creating a violin plot using seaborn
sns.violinplot(x=df['gender'], y=df['vintage'])
plt.title('Violin Plot of Vintage by Gender')
plt.show()

# %%
# Creating a countplot with hue for occupation
sns.countplot(x=df['gender'],hue=df['occupation'])
plt.title('Count of Genders by Occupation')
plt.show()

# %%
# Calculate the average current_balance for each gender and occupation combination
average_balance = df.groupby(['gender', 'occupation']).mean().reset_index()
average_balance
# Out:
# C:\Users\Prashant\AppData\Local\Temp\ipykernel_10336\192149634.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   average_balance = df.groupby(['gender', 'occupation']).mean().reset_index()
#    gender     occupation      vintage        age  dependents  current_balance  \
# 0  Female        company  2102.000000  45.333333    0.000000      3920.570000
# 1  Female        retired  2381.172727  71.786364    0.059091      8528.989545
# 2  Female       salaried  2389.182524  41.491262    0.154369      6703.122583
# 3  Female  self_employed  2400.376715  49.546702    0.123506      6692.574241
# 4  Female        student  2391.149201  19.090586    0.012433      4305.179236
# 5    Male        company  2394.750000  72.650000    0.400000      7874.087000
# 6    Male        retired  2378.124324  72.487568    0.193514      6039.143059
# 7    Male       salaried  2397.337385  45.006630    0.538490      7080.190589
# 8    Male  self_employed  2385.658555  50.915200    0.649944      8720.581526
# 9    Male        student  2404.919056  19.224283    0.153457      4739.007386
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# 0                 7252.133333                    5572.700000
# 1                 9451.870227                    7896.080455
# 2                 6741.694728                    6695.843087
# 3                 6740.108853                    6964.274668
# 4                 4406.522451                    4436.754103
# 5                 4870.325500                    5224.650500
# 6                 5924.387243                    6071.070757
# 7                 7348.304184                    7200.171610
# 8                 8863.783117                    8930.516196
# 9                 4722.288921                    4736.710995
#
#    average_monthly_balance_prevQ2  current_month_credit  \
# 0                     4824.086667            143.160000
# 1                     6327.859136           2553.502682
# 2                     6390.801631           1876.335010
# 3                     6166.738617           2740.843477
# 4                     4085.429734           1044.931083
# 5                     3389.979000           4217.837000
# 6                     5756.207232           1562.275632
# 7                     7002.286497           2787.681838
# 8                     9246.957025           5105.488308
# 9                     4163.574081            674.112597
#
#    previous_month_credit  current_month_debit  previous_month_debit  \
# 0            2619.346667          3474.723333              0.300000
# 1            4329.330818          2781.452818           1709.100909
# 2            2064.358214          1900.309117           2656.508058
# 3            2285.946144          3074.981490           2655.932795
# 4             977.965044          1324.851208           1200.126359
# 5            4132.604000          2081.957500            947.872000
# 6            2319.761784          1969.855092           2536.595276
# 7            3449.761510          3139.163381           3641.271901
# 8            5305.138214          5176.672610           4967.877739
# 9             965.661855           788.561889           1073.295042
#
#    current_month_balance  previous_month_balance
# 0            4662.813333             7037.083333
# 1            8791.701773             8270.855773
# 2            6548.922350             6762.056612
# 3            6666.186259             6954.300821
# 4            4414.842966             4487.790515
# 5            5889.764500             5150.865000
# 6            5964.422303             5966.752670
# 7            7138.344052             7271.656807
# 8            9011.869558             8908.496601
# 9            4763.471771             4698.666745

# %%
# Creating a bar plot
sns.barplot(x='gender', y='current_balance', hue='occupation', data=average_balance)
plt.title('Average Current Balance by Gender and Occupation')
plt.show()

# %% [markdown]
# # Box-Cox Tranformation

# %%
df['vintage'].skew()
# Out:
# -1.4197175931628572

# %%
sns.histplot(df['vintage'], bins=30, kde=True) 
plt.title('Distribution of Vintage')
# Out:
# Text(0.5, 1.0, 'Distribution of Vintage')

# %%
df['vintage'].apply(np.log10).skew()
# Out:
# -2.3156555019630125

# %%
import numpy as np
sns.histplot(np.log10(df['vintage']), bins=30, kde=True) 
plt.title('Distribution of Vintage: after log transform')
# Out:
# Text(0.5, 1.0, 'Distribution of Vintage: after log transform')

# %%
sns.histplot(np.sqrt(df['vintage']), bins=30, kde=True) 
plt.title('Distribution of Vintage: after SQRT transform')
# Out:
# Text(0.5, 1.0, 'Distribution of Vintage: after SQRT transform')

# %%
df['vintage'].apply(np.sqrt).skew()
# Out:
# -1.7796946264780211

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

SC = StandardScaler()  # stnadardize the data to zero means, and unit standard deviation
df['vintage_std'] = SC.fit_transform(df[['vintage']])

minmax = MinMaxScaler() # rescale the data such that the min value is now 0, and max value is 1
df['vintage_minmax'] = minmax.fit_transform(df[['vintage']])

# %%
df[['vintage', 'vintage_std', 'vintage_minmax']]
# Out:
#        vintage  vintage_std  vintage_minmax
# 0         2401     0.031484        0.839607
# 1         2648     0.937978        0.945252
# 2         2494     0.372796        0.879384
# 3         2629     0.868248        0.937126
# 4         1879    -1.884263        0.616339
# ...        ...          ...             ...
# 15924     2175    -0.797939        0.742943
# 15925     2500     0.394816        0.881950
# 15926     2470     0.284715        0.869119
# 15927     2537     0.530606        0.897776
# 15928     2287    -0.386897        0.790847
#
# [15929 rows x 3 columns]

# %%
plt.figure(figsize=(12, 10))

plt.subplot(2,2,1)
sns.histplot(df['vintage'], bins=30, kde=True) 
plt.title('Original Distribution of Vintage')

plt.subplot(2,2,2)
sns.histplot(df['vintage_std'], bins=30, kde=True) 
plt.title('Distribution of Vintage after Standardization')

plt.subplot(2,2,3)
sns.histplot(df['vintage_minmax'], bins=30, kde=True) 
plt.title('Distribution of Vintage after MinMax Scaling')

plt.show()

# %%
from sklearn.preprocessing import PowerTransformer
boxcox = PowerTransformer(method='box-cox')  # use 'yeo-johnson' if your data contains both negative and zero values too.
df['vintage_boxcox'] = boxcox.fit_transform(df[['vintage']])

# %%
plt.figure(figsize=(12, 10))

plt.subplot(2,2,1)
sns.histplot(df['vintage'], bins=30, kde=True) 
plt.title('Original Distribution of Vintage')

plt.subplot(2,2,2)
sns.histplot(df['vintage_std'], bins=30, kde=True) 
plt.title('Distribution of Vintage after Standardization')

plt.subplot(2,2,3)
sns.histplot(df['vintage_minmax'], bins=30, kde=True) 
plt.title('Distribution of Vintage after MinMax Scaling')

plt.subplot(2,2,4)
sns.histplot(df['vintage_boxcox'], bins=30, kde=True) 
plt.title('Distribution of Vintage after Box-Cox Transfom')


plt.show()
